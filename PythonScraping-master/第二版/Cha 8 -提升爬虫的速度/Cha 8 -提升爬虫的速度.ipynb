# %% [markdown]
# # 7.2 多线程爬虫

# %% [markdown]
# ## 7.2.1简单单线程爬虫

# %%
proxies = {'https': 'https://web-proxy.oa.com:8080',
           'http': 'http://web-proxy.oa.com:8080'}

# %%
import requests
import time

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)

start = time.time()
for eachone in link_list:
    try:
        r = requests.get(eachone)
        print (r.status_code, eachone)
    except Exception as e: 
        print('Error: ', e)
end = time.time()
print ('串行的总时间为：', end-start)
# Out:
# 200 http://www.baidu.com
# 200 http://www.qq.com
# 200 http://www.naver.com
# 200 http://www.taobao.com
# 200 http://www.reddit.com
# 200 http://www.sohu.com
# 200 http://www.tmall.com
# 200 http://www.sina.com.cn
# 200 http://www.daum.net
# 200 http://www.jd.com
# 200 http://www.360.cn
# 200 http://www.weibo.com
# 200 http://www.aliexpress.com
# 200 http://www.linkedin.com
# 200 http://www.alipay.com
# 200 http://www.hao123.com
# 200 http://www.csdn.net
# 200 http://www.youth.cn
# 200 http://www.live.com
# 200 http://www.tianya.cn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6bc156f0704c> in <module>
#      13 for eachone in link_list:
#      14     try:
# ---> 15         r = requests.get(eachone)
#      16         print (r.status_code, eachone)
#      17     except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
file_list
# Out:
# ['0\thttp://www.baidu.com\n',
#  '1\thttp://www.qq.com\n',
#  '2\thttp://www.naver.com\n',
#  '3\thttp://www.taobao.com\n',
#  '4\thttp://www.reddit.com\n',
#  '5\thttp://www.sohu.com\n',
#  '6\thttp://www.tmall.com\n',
#  '7\thttp://www.sina.com.cn\n',
#  '8\thttp://www.daum.net\n',
#  '9\thttp://www.jd.com\n',
#  '10\thttp://www.360.cn\n',
#  '11\thttp://www.weibo.com\n',
#  '12\thttp://www.aliexpress.com\n',
#  '13\thttp://www.linkedin.com\n',
#  '14\thttp://www.alipay.com\n',
#  '15\thttp://www.hao123.com\n',
#  '16\thttp://www.csdn.net\n',
#  '17\thttp://www.youth.cn\n',
#  '18\thttp://www.live.com\n',
#  '19\thttp://www.tianya.cn\n',
#  '20\thttp://www.microsoftonline.com\n',
#  '21\thttp://www.office.com\n',
#  '22\thttp://www.soso.com\n',
#  '23\thttp://www.so.com\n',
#  '24\thttp://www.gmw.cn\n',
#  '25\thttp://www.china.com\n',
#  '26\thttp://www.nate.com\n',
#  '27\thttp://www.huaban.com\n',
#  '28\thttp://www.bing.com\n',
#  '29\thttp://www.xinhuanet.com\n',
#  '30\thttp://www.youku.com\n',
#  '31\thttp://www.zhihu.com\n',
#  '32\thttp://www.cctv.com\n',
#  '33\thttp://www.airasia.com\n',
#  '34\thttp://www.douyu.com\n',
#  '35\thttp://www.babytree.com\n',
#  '36\thttp://www.apple.com\n',
#  '37\thttp://www.sogou.com\n',
#  '38\thttp://www.china.com.cn\n',
#  '39\thttp://www.yelp.com\n',
#  '40\thttp://www.ocbc.com\n',
#  '41\thttp://www.microsoft.com\n',
#  '42\thttp://www.mama.cn\n',
#  '782\thttp://www.silkair.com\n',
#  '783\thttp://www.313.cn\n',
#  '784\thttp://www.ssl-images-amazon.com\n',
#  '785\thttp://www.eepw.com.cn\n',
#  '786\thttp://www.gs307.com\n',
#  '787\thttp://www.yindou.com\n',
#  '788\thttp://www.i1515.com\n',
#  '789\thttp://www.imiker.com\n',
#  '790\thttp://www.lvmama.com\n',
#  '791\thttp://www.louisvuitton.com\n',
#  '792\thttp://www.nowgoal.com\n',
#  '793\thttp://www.makeding.com\n',
#  '794\thttp://www.xz7.com\n',
#  '795\thttp://www.guitarchina.com\n',
#  '796\thttp://www.wto168.net\n',
#  '797\thttp://www.abchina.com\n',
#  '798\thttp://www.fzdm.com\n',
#  '799\thttp://www.ichacha.net\n',
#  '800\thttp://www.1024sj.com\n',
#  '801\thttp://www.ef43.com.cn\n',
#  '802\thttp://www.newrank.cn\n',
#  '803\thttp://www.ceair.com\n',
#  '804\thttp://www.zimuku.net\n',
#  '805\thttp://www.ppkoo.com\n',
#  '806\thttp://www.jc35.com\n',
#  '807\thttp://www.dnspod.cn\n',
#  '808\thttp://www.hsw.cn\n',
#  '809\thttp://www.caixin.com\n',
#  '810\thttp://www.manmanbuy.com\n',
#  '811\thttp://www.23us.com\n',
#  '812\thttp://www.asus.com\n',
#  '813\thttp://www.zoosnet.net\n',
#  '814\thttp://www.xp510.com\n',
#  '815\thttp://www.vgtime.com\n',
#  '816\thttp://www.qiushibaike.com\n',
#  '817\thttp://www.jinshuju.net\n',
#  '818\thttp://www.115.com\n',
#  '819\thttp://www.3367.com\n',
#  '820\thttp://www.fanli.com\n',
#  '821\thttp://www.newcger.com\n',
#  '822\thttp://www.kepu.net.cn\n',
#  '823\thttp://www.findlaw.cn\n',
#  '824\thttp://www.jiumei.com\n',
#  '825\thttp://www.gkstk.com\n',
#  '826\thttp://www.ihg.com\n',
#  '827\thttp://www.blizzard.com\n',
#  '828\thttp://www.lenovo.com\n',
#  '829\thttp://www.longau.com\n',
#  '830\thttp://www.seedit.com\n',
#  '831\thttp://www.ofweek.com\n',
#  '832\thttp://www.61baobao.com\n',
#  '833\thttp://www.400.cn\n',
#  '834\thttp://www.wines-info.com\n',
#  '835\thttp://www.innisfree.com\n',
#  '836\thttp://www.weather.com.cn\n',
#  '837\thttp://www.che168.com\n',
#  '838\thttp://www.dilidili.wang\n',
#  '839\thttp://www.7po.com\n',
#  '840\thttp://www.qiushibaike.com\n',
#  '841\thttp://www.9r.cn\n',
#  '842\thttp://www.weather.com.cn\n',
#  '843\thttp://www.107cine.com\n',
#  '844\thttp://www.coolapk.com\n',
#  '845\thttp://www.ixueshu.com\n',
#  '846\thttp://www.iplaysoft.com\n',
#  '847\thttp://www.blizzard.cn\n',
#  '848\thttp://www.dangbei.com\n',
#  '849\thttp://www.hellorf.com\n',
#  '850\thttp://www.21food.cn\n',
#  '851\thttp://www.libaclub.com\n',
#  '852\thttp://www.outofmemory.cn\n',
#  '853\thttp://www.ele.me\n',
#  '854\thttp://www.shihuo.cn\n',
# %%
import _thread
import time
 
# 为线程定义一个函数
def print_time(threadName, delay):
    count = 0
    while count < 3:
        time.sleep(delay)
        count += 1
        print (threadName, time.ctime())
        
_thread.start_new_thread(print_time, ("Thread-1", 1))
_thread.start_new_thread(print_time, ("Thread-2", 2))
print ("Main Finished")
# Out:
# Main Finished
# Thread-1 Mon Dec 21 13:11:58 2020
# Thread-2 Mon Dec 21 13:11:59 2020
# Thread-1 Mon Dec 21 13:11:59 2020
# Thread-1 Mon Dec 21 13:12:00 2020
# Thread-2 Mon Dec 21 13:12:01 2020
# Thread-2 Mon Dec 21 13:12:03 2020

# %%
import threading
import time
 
class myThread (threading.Thread):
    def __init__(self, name, delay):
        threading.Thread.__init__(self)
        self.name = name
        self.delay = delay
    def run(self):
        print ("Starting " + self.name)
        print_time(self.name, self.delay)
        print ("Exiting " + self.name)
        
def print_time(threadName, delay):
    counter = 0
    while counter < 3:
        time.sleep(delay)
        print (threadName, time.ctime())
        counter += 1
        
threads = []

# 创建新线程
thread1 = myThread("Thread-1", 1)
thread2 = myThread("Thread-2", 2)
 
# 开启新线程
thread1.start()
thread2.start()
 
# 添加线程到线程列表
threads.append(thread1)
threads.append(thread2)
 
# 等待所有线程完成
for t in threads:
    t.join()
    
print ("Exiting Main Thread")
# Out:
# Starting Thread-1
# Starting Thread-2
# Exiting Main Thread
# Thread-1 Mon Dec 21 13:13:42 2020
# Thread-2Thread-1 Mon Dec 21 13:13:43 2020
#  Mon Dec 21 13:13:43 2020
# Thread-1 Mon Dec 21 13:13:44 2020
# Exiting Thread-1
# Thread-2 Mon Dec 21 13:13:45 2020
# Thread-2 Mon Dec 21 13:13:47 2020
# Exiting Thread-2

# %% [markdown]
# ## 7.2.3 多线程爬虫

# %%
import threading
import requests
import time

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)

start = time.time()
class myThread (threading.Thread):
    def __init__(self, name, link_range):
        threading.Thread.__init__(self)
        self.name = name
        self.link_range = link_range
    def run(self):
        print ("Starting " + self.name)
        crawler(self.name, self.link_range)
        print ("Exiting " + self.name)
        
def crawler(threadName, link_range):
    for i in range(link_range[0],link_range[1]+1):
        try:
            r = requests.get(link_list[i], timeout=20)
            print (threadName, r.status_code, link_list[i])
        except Exception as e: 
            print(threadName, 'Error: ', e)
        
thread_list = []
link_range_list = [(0,200),(201,400),(401,600),(601,800),(801,1000)]

# 创建新线程
for i in range(1,6):
    thread = myThread("Thread-" + str(i), link_range_list[i-1])
    thread.start()
    thread_list.append(thread)
    
# 等待所有线程完成
for thread in thread_list:
    thread.join()

end = time.time()
print ('简单多线程爬虫的总时间为：', end-start)
print ("Exiting Main Thread")
# Out:
# Starting Thread-1Starting Thread-2
#
# Starting Thread-3Starting Thread-4
#
# Starting Thread-5
# Thread-1 200 http://www.baidu.com
# Thread-5 200 http://www.ef43.com.cn
# Thread-3 200 http://www.yy.com
# Thread-2 200 http://www.cnki.net
# Thread-1 200 http://www.qq.com
# Thread-4 200 http://www.java.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xp510.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.duowan.com
# Thread-5 200 http://www.newrank.cn
# Thread-5 403 http://www.vgtime.com
# Thread-5 200 http://www.ceair.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.microsoftonline.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.mbalib.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.zimuku.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.surveymonkey.com
# Thread-1 200 http://www.naver.com
# Thread-5 403 http://www.ppkoo.com
# Thread-2 200 http://www.tower.im
# Thread-1 200 http://www.taobao.com
# Thread-5 200 http://www.jc35.com
# Thread-5 200 http://www.dnspod.cn
# Thread-5 200 http://www.hsw.cn
# Thread-5 200 http://www.caixin.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.baiducontent.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 403 http://www.acfun.cn
# Thread-4 403 http://www.hdpfans.com
# Thread-2 200 http://www.people.com.cn
# Thread-4 521 http://www.thinkphp.cn
# Thread-4 200 http://www.2345.com
# Thread-4 200 http://www.baoku.com
# Thread-4 200 http://www.tiancity.com
# Thread-3 200 http://www.wanfangdata.com.cn
# Thread-4 403 http://www.bcsh.com
# Thread-4 200 http://www.bozhong.com
# Thread-1 200 http://www.reddit.com
# Thread-4 200 http://www.zhiding.cn
# Thread-4 200 http://www.longzhu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.xjtour.com
# Thread-4 521 http://www.kancloud.cn
# Thread-1 200 http://www.tmall.com
# Thread-2 200 http://www.jmw.com.cn
# Thread-1 200 http://www.sina.com.cn
# Thread-5 200 http://www.manmanbuy.com
# Thread-2 200 http://www.worktile.com
# Thread-4 200 http://www.open-open.com
# Thread-2 200 http://www.newsmth.net
# Thread-3 200 http://www.fengniao.com
# Thread-4 200 http://www.itpub.net
# Thread-4 200 http://www.elong.com
# Thread-3 200 http://www.fangdd.com
# Thread-2 200 http://www.vmall.com
# Thread-1 200 http://www.daum.net
# Thread-2 200 http://www.07073.com
# Thread-3 200 http://www.htc.com
# Thread-4 200 http://www.pchome.net
# Thread-4 200 http://www.pps.tv
# Thread-4 200 http://www.qinqinbaby.com
# Thread-5 403 http://www.23us.com
# Thread-5 200 http://www.qiushibaike.com
# Thread-2 200 http://www.qyer.com
# Thread-5 403 http://www.asus.com
# Thread-4 200 http://www.qinqinbaby.com
# Thread-2 200 http://www.hujiang.com
# Thread-5 200 http://www.zoosnet.net
# Thread-3 200 http://www.jdzj.com
# Thread-1 200 http://www.office.com
# Thread-1 200 http://www.soso.com
# Thread-5 200 http://www.jinshuju.net
# Thread-5 200 http://www.115.com
# Thread-1 200 http://www.so.com
# Thread-3 200 http://www.pcauto.com.cn
# Thread-1 200 http://www.gmw.cn
# Thread-1 200 http://www.china.com
# Thread-3 200 http://www.kaola.com
# Thread-1 200 http://www.nate.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ibuying.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 403 http://www.chouti.com
# Thread-3 200 http://www.71.net
# Thread-1 200 http://www.jd.com
# Thread-3 200 http://www.hrloo.com
# Thread-4 200 http://www.chuandong.com
# Thread-1 200 http://www.360.cn
# Thread-5 200 http://www.3367.com
# Thread-4 200 http://www.chuandong.com
# Thread-4 200 http://www.coding.net
# Thread-5 200 http://www.fanli.com
# Thread-3 200 http://www.meizu.com
# Thread-4 200 http://www.coding.net
# Thread-4Thread-1 200 http://www.weibo.com
#  200 http://www.yidianzixun.com
# Thread-4 200 http://www.yidianzixun.com
# Thread-5 200 http://www.newcger.com
# Thread-3 200 http://www.miercn.com
# Thread-4 200 http://www.51nb.com
# Thread-4 200 http://www.51nb.com
# Thread-3 200 http://www.fengniao.com
# Thread-5 200 http://www.kepu.net.cn
# Thread-4 200 http://www.dhgate.com
# Thread-4 200 http://www.dhgate.com
# Thread-3 200 http://www.fangdd.com
# Thread-3 200 http://www.htc.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnnic.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.kuaidi100.com
# Thread-5 200 http://www.findlaw.cn
# Thread-1 200 http://www.aliexpress.com
# Thread-3 200 http://www.jdzj.com
# Thread-2 200 http://www.meituan.com
# Thread-3 200 http://www.pcauto.com.cn
# Thread-5 404 http://www.jiumei.com
# Thread-1 200 http://www.linkedin.com
# Thread-5 403 http://www.gkstk.com
# Thread-2 200 http://www.yinxiang.com
# Thread-1 200 http://www.alipay.com
# Thread-2 200 http://www.ngacn.cc
# Thread-3 200 http://www.kaola.com
# Thread-2 403 http://www.smzdm.com
# Thread-2 200 http://www.ccb.com
# Thread-3 200 http://www.kuaidi100.com
# Thread-5 200 http://www.ihg.com
# Thread-2 200 http://www.ali213.net
# Thread-1 200 http://www.hao123.com
# Thread-1 200 http://www.csdn.net
# Thread-5 200 http://www.blizzard.com
# Thread-1 200 http://www.youth.cn
# Thread-5 403 http://www.lenovo.com
# Thread-2 200 http://www.alibaba-inc.com
# Thread-2 200 http://www.3158.cn
# Thread-5 200 http://www.longau.com
# Thread-2 200 http://www.vmall.com
# Thread-1 200 http://www.live.com
# Thread-1 200 http://www.tianya.cn
# Thread-5 200 http://www.seedit.com
# Thread-2 200 http://www.nike.com
# Thread-2 200 http://www.eqxiu.com
# Thread-5 200 http://www.ofweek.com
# Thread-2 403 http://www.jandan.net
# Thread-5 200 http://www.61baobao.com
# Thread-5 200 http://www.400.cn
# Thread-4Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.10086.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.10086.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.office365.com
# Thread-3 200 http://www.yougov.com
# Thread-3 200 http://www.yougov.com
# Thread-5 200 http://www.wines-info.com
# Thread-2 200 http://www.imooc.com
# Thread-3 200 http://www.ku6.com
# Thread-3 200 http://www.ku6.com
# Thread-2 200 http://www.ikea.com
# Thread-3 200 http://www.sanwen8.cn
# Thread-3 200 http://www.sanwen8.cn
# Thread-3 200 http://www.yiwugou.com
# Thread-3 200 http://www.yiwugou.com
# Thread-1 200 http://www.huaban.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.hao6v.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.5acbd.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.hao6v.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.atobo.com.cn
# Thread-5 200 http://www.innisfree.com
# Thread-5 200 http://www.weather.com.cn
# Thread-1 200 http://www.bing.com
# Thread-1 200 http://www.xinhuanet.com
# Thread-5 200 http://www.che168.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.dilidili.wang/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.7po.com
# Thread-1 200 http://www.youku.com
# Thread-5 200 http://www.qiushibaike.com
# Thread-1 403 http://www.zhihu.com
# Thread-1 200 http://www.cctv.com
# Thread-5 200 http://www.9r.cn
# Thread-5 200 http://www.weather.com.cn
# Thread-4 200 http://www.5acbd.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 200 http://www.107cine.com
# Thread-4 200 http://www.atobo.com.cn
# Thread-5 200 http://www.coolapk.com
# Thread-2 200 http://www.ly.com
# Thread-2 200 http://www.epwk.com
# Thread-5 200 http://www.ixueshu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xp510.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.kubo365.com
# Thread-2 200 http://www.tudou.com
# Thread-5 403 http://www.vgtime.com
# Thread-5 200 http://www.iplaysoft.com
# Thread-4 404 http://www.111cn.net
# Thread-5 200 http://www.qiushibaike.com
# Thread-4 200 http://www.zhongmin.cn
# Thread-5 200 http://www.blizzard.cn
# Thread-5 200 http://www.dangbei.com
# Thread-4 503 http://www.weiyangx.com
# Thread-2 200 http://www.leagueoflegends.com
# Thread-4 200 http://www.juesheng.com
# Thread-5 200 http://www.jinshuju.net
# Thread-1 200 http://www.airasia.com
# Thread-5 200 http://www.115.com
# Thread-4 200 http://www.uuu9.com
# Thread-1 200 http://www.douyu.com
# Thread-5 200 http://www.hellorf.com
# Thread-4 200 http://www.siilu.com
# Thread-3 200 http://www.lottedfs.com
# Thread-4 200 http://www.pconline.com.cn
# Thread-1 200 http://www.babytree.com
# Thread-3 200 http://www.cisco.com
# Thread-4 200 http://www.kubo365.com
# Thread-1 200 http://www.apple.com
# Thread-4 404 http://www.111cn.net
# Thread-3 200 http://www.lottedfs.com
# Thread-4 200 http://www.dji.com
# Thread-1 200 http://www.sogou.com
# Thread-3 200 http://www.cisco.com
# Thread-4 200 http://www.zhongmin.cn
# Thread-1 200 http://www.china.com.cn
# Thread-3 200 http://www.wallstreetcn.com
# Thread-4 503 http://www.weiyangx.com
# Thread-3 200 http://www.gamedog.cn
# Thread-4 200 http://www.juesheng.com
# Thread-3 200 http://www.wallstreetcn.com
# Thread-3 200 http://www.gamedog.cn
# Thread-4 200 http://www.uuu9.com
# Thread-4 200 http://www.west.cn
# Thread-3 200 http://www.tencent.com
# Thread-4 200 http://www.siilu.com
# Thread-4 Error:  HTTPSConnectionPool(host='www.51zxw.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-4 200 http://www.pconline.com.cn
# Thread-3 200 http://www.tencent.com
# Thread-4 200 http://www.ctfile.com
# Thread-4 200 http://www.dji.com
# Thread-1 200 http://www.yelp.com
# Thread-4 200 http://www.west.cn
# Thread-2 200 http://www.aa.com
# Thread-4 Error:  HTTPSConnectionPool(host='www.51zxw.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-4 200 http://www.ctfile.com
# Thread-1 200 http://www.ocbc.com
# Thread-2 200 http://www.garena.com
# Thread-1 200 http://www.microsoft.com
# Thread-2 521 http://www.mafengwo.cn
# Thread-2 200 http://www.ifensi.com
# Thread-1 200 http://www.mama.cn
# Thread-1 200 http://www.bitauto.com
# Thread-2 477 http://www.pptv.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.fobshanghai.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.3367.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.fanli.com
# Thread-5 200 http://www.newcger.com
# Thread-5 200 http://www.kepu.net.cn
# Thread-5 200 http://www.findlaw.cn
# Thread-5 404 http://www.jiumei.com
# Thread-5 403 http://www.gkstk.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.tvhome.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.ihg.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.tvhome.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.microsoftonline.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.office.com
# Thread-1 200 http://www.soso.com
# Thread-3 200 http://www.xbox.com
# Thread-3 200 http://www.xbox.com
# Thread-1 200 http://www.so.com
# Thread-3 200 http://www.cr173.com
# Thread-3 200 http://www.cr173.com
# Thread-3 200 http://www.onlinedown.net
# Thread-1 200 http://www.bankofamerica.com
# Thread-1 200 http://www.gmw.cn
# Thread-3 200 http://www.onlinedown.net
# Thread-1 200 http://www.china.com
# Thread-1 200 http://www.nate.com
# Thread-1 200 http://www.1688.com
# Thread-3 200 http://www.ebay.com.hk
# Thread-3 200 http://www.ebay.com.hk
# Thread-1 200 http://www.stackoverflow.com
# Thread-1 200 http://www.163.com
# Thread-5 200 http://www.blizzard.com
# Thread-1 200 http://www.39.net
# Thread-5 403 http://www.lenovo.com
# Thread-5 200 http://www.longau.com
# Thread-1 200 http://www.cnblogs.com
# Thread-5 200 http://www.seedit.com
# Thread-5 200 http://www.ofweek.com
# Thread-1 200 http://www.bilibili.com
# Thread-3 200 http://www.searchs.cn
# Thread-3 200 http://www.searchs.cn
# Thread-3 200 http://www.17track.net
# Thread-5 200 http://www.61baobao.com
# Thread-3 200 http://www.17track.net
# Thread-5 200 http://www.400.cn
# Thread-5 200 http://www.wines-info.com
# Thread-5 200 http://www.innisfree.com
# Thread-5 200 http://www.weather.com.cn
# Thread-5 200 http://www.che168.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.dilidili.wang/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.7po.com
# Thread-3 200 http://www.hyundai.com
# Thread-5 200 http://www.qiushibaike.com
# Thread-5 200 http://www.9r.cn
# Thread-5 200 http://www.weather.com.cn
# Thread-3 200 http://www.hyundai.com
# Thread-3 200 http://www.baixing.com
# Thread-3 503 http://www.258.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3 200 http://www.baixing.com
# Thread-2 200 http://www.ly.com
# Thread-3 503 http://www.258.com
# Thread-2 200 http://www.epwk.com
# Thread-5 200 http://www.107cine.com
# Thread-2 200 http://www.asiamiles.com
# Thread-1 200 http://www.huaban.com
# Thread-2 403 http://www.znds.com
# Thread-5 200 http://www.coolapk.com
# Thread-3 200 http://www.cn2che.com
# Thread-2 200 http://www.tudou.com
# Thread-1 200 http://www.bing.com
# Thread-1 200 http://www.xinhuanet.com
# Thread-2 200 http://www.hc360.com
# Thread-5 200 http://www.ixueshu.com
# Thread-5 200 http://www.iplaysoft.com
# Thread-1 200 http://www.youku.com
# Thread-1 403 http://www.zhihu.com
# Thread-5 200 http://www.blizzard.cn
# Thread-2 200 http://www.leagueoflegends.com
# Thread-1 200 http://www.cctv.com
# Thread-5 200 http://www.dangbei.com
# Thread-3 200 http://www.cn2che.com
# Thread-2 200 http://www.job853.com
# Thread-2 200 http://www.sf-express.com
# Thread-5 200 http://www.hellorf.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.interpark.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.huanqiu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnzz.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.chinadaily.com.cn
# Thread-1 502 http://www.openrice.com
# Thread-5 200 http://www.21food.cn
# Thread-1 200 http://www.msn.com
# Thread-1 200 http://www.k618.cn
# Thread-1 200 http://www.yesky.com
# Thread-2 200 http://www.lianjia.com
# Thread-1 200 http://www.caijing.com.cn
# Thread-5 200 http://www.libaclub.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.outofmemory.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.guokr.com
# Thread-2 200 http://www.cmbchina.com
# Thread-2 200 http://www.aa.com
# Thread-5 200 http://www.ele.me
# Thread-5 200 http://www.shihuo.cn
# Thread-1 200 http://www.airasia.com
# Thread-2 200 http://www.garena.com
# Thread-2 521 http://www.mafengwo.cn
# Thread-1 200 http://www.douyu.com
# Thread-2 200 http://www.ifensi.com
# Thread-1 200 http://www.babytree.com
# Thread-2 477 http://www.pptv.com
# Thread-1 200 http://www.emirates.com
# Thread-1 200 http://www.apple.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.fobshanghai.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sogou.com
# Thread-1 503 http://www.amazon.cn
# Thread-1 200 http://www.china.com.cn
# Thread-3 503 http://www.pudn.com
# Thread-3 503 http://www.pudn.com
# Thread-2 200 http://www.modernweekly.com
# Thread-1 200 http://www.aliyun.com
# Thread-2 200 http://www.ynet.com
# Thread-3 200 http://www.dv37.com
# Thread-1 200 http://www.eastday.com
# Thread-3 200 http://www.dv37.com
# Thread-1 200 http://www.youdao.com
# Thread-2 200 http://www.dell.com
# Thread-1 200 http://www.oeeee.com
# Thread-3 200 http://www.dv37.com
# Thread-3 200 http://www.dv37.com
# Thread-2 200 http://www.dict.cn
# Thread-1 200 http://www.ci123.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 Thread-1 200200 http://www.baike.com
#  http://www.yelp.com
# Thread-2 200 http://www.asiamiles.com
# Thread-3 200 http://www.uisdc.com
# Thread-2 403 http://www.znds.com
# Thread-1 200 http://www.adobe.com
# Thread-3 200 http://www.uisdc.com
# Thread-2 200 http://www.hc360.com
# Thread-2 200 http://www.job853.com
# Thread-1 200 http://www.rednet.cn
# Thread-5 200 http://www.libaclub.com
# Thread-2 200 http://www.sf-express.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.outofmemory.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sojump.com
# Thread-3 200 http://www.sojump.com
# Thread-5 200 http://www.ele.me
# Thread-3Thread-3 200 http://www.d1net.com
#  200 http://www.d1net.com
# Thread-5 200 http://www.shihuo.cn
# Thread-3 200 http://www.ganji.com
# Thread-3 200 http://www.ganji.com
# Thread-1 200 http://www.iqiyi.com
# Thread-1 200 http://www.ocbc.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.lianjia.com
# Thread-3 200 http://www.jobbole.com
# Thread-3 200 http://www.jobbole.com
# Thread-2 200 http://www.guokr.com
# Thread-1 200 http://www.microsoft.com
# Thread-2 200 http://www.cmbchina.com
# Thread-1 200 http://www.mama.cn
# Thread-1 200 http://www.bitauto.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.modernweekly.com
# Thread-2 200 http://www.ynet.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://ww16.zmz2017.com/?sub1=20201222-1722-247e-9413-2699cbda787c (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://ww16.zmz2017.com/?sub1=20201222-1722-25b4-8989-92a481b380cf (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.dell.com
# Thread-4 200 http://www.smm.cn
# Thread-2 200 http://www.dict.cn
# Thread-5 200 http://www.zybuluo.com
# Thread-5 200 http://www.zybuluo.com
# Thread-4 200 http://www.smm.cn
# Thread-1 200 http://www.bankofamerica.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yinyuetai.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.aizhan.com
# Thread-1 200 http://www.1688.com
# Thread-2 200 http://www.gome.com.cn
# Thread-2 403 http://www.meishichina.com
# Thread-4 200 http://www.shejis.com
# Thread-2 200 http://www.51hejia.com
# Thread-3 200 http://www.pearsoncmg.com
# Thread-2 200 http://www.ule.com
# Thread-3 200 http://www.pearsoncmg.com
# Thread-3 503 http://www.kongfz.com
# Thread-3 503 http://www.kongfz.com
# Thread-2 403 http://www.ea3w.com
# Thread-4 200 http://www.shejis.com
# Thread-2 200 http://www.saraba1st.com
# Thread-1 200 http://www.stackoverflow.com
# Thread-1 200 http://www.163.com
# Thread-1 200 http://www.39.net
# Thread-2 200 http://www.chsi.com.cn
# Thread-1 200 http://www.cnblogs.com
# Thread-3 200 http://www.365jilin.com
# Thread-3 200 http://www.365jilin.com
# Thread-2 200 http://www.vlive.tv
# Thread-2 200 http://www.sonhoo.com
# Thread-1 200 http://www.bilibili.com
# Thread-1 200 http://www.wemakeprice.com
# Thread-1 418 http://www.douban.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yinyuetai.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.aizhan.com
# Thread-1 200 http://www.familydoctor.com.cn
# Thread-3 200 http://www.strawberrynet.com
# Thread-3 200 http://www.strawberrynet.com
# Thread-2 200 http://www.gome.com.cn
# Thread-3Thread-3 503 http://www.11467.com
#  503 http://www.11467.com
# Thread-1 200 http://www.agoda.com
# Thread-1 200 http://www.jrj.com.cn
# Thread-2 403 http://www.meishichina.com
# Thread-3 403 http://www.jobui.com
# Thread-3 403 http://www.jobui.com
# Thread-3 200 http://www.hh010.com
# Thread-3 200 http://www.hh010.com
# Thread-2 200 http://www.51hejia.com
# Thread-2 200 http://www.ule.com
# Thread-2 403 http://www.ea3w.com
# Thread-3 200 http://www.teambition.com
# Thread-3 200 http://www.teambition.com
# Thread-3 200 http://www.woshipm.com
# Thread-3 200 http://www.woshipm.com
# Thread-2 200 http://www.saraba1st.com
# Thread-2 200 http://www.chsi.com.cn
# Thread-2 200 http://www.vlive.tv
# Thread-2 200 http://www.sonhoo.com
# Thread-1 200 http://www.read01.com
# Thread-1 200 http://www.17ok.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.interpark.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.chinaz.com
# Thread-1 200 http://www.huanqiu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnzz.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.chinadaily.com.cn
# Thread-1 502 http://www.openrice.com
# Thread-1 200 http://www.youboy.com
# Thread-1 200 http://www.msn.com
# Thread-1 200 http://www.k618.cn
# Thread-1 200 http://www.yesky.com
# Thread-1 200 http://www.caijing.com.cn
# Thread-1 200 http://www.emirates.com
# Thread-1 503 http://www.amazon.cn
# Thread-1 200 http://www.aliyun.com
# Thread-1 200 http://www.eastday.com
# Thread-1 200 http://www.youdao.com
# Thread-1 200 http://www.oeeee.com
# Thread-1 200 http://www.ci123.com
# Thread-1 200 http://www.baike.com
# Thread-1 200 http://www.adobe.com
# Thread-1 200 http://www.rednet.cn
# Thread-1 200 http://www.iqiyi.com
# Thread-3 200 http://www.lge.com
# Thread-1 200 http://www.wemakeprice.com
# Thread-1 418 http://www.douban.com
# Thread-1 200 http://www.familydoctor.com.cn
# Thread-1 200 http://www.agoda.com
# Thread-1 200 http://www.jrj.com.cn
# Thread-5Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.66ys.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.66ys.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.kanxi.cc
# Thread-5 200 http://www.sczw.com
# Thread-5 200 http://www.sczw.com
# Thread-1 200 http://www.read01.com
# Thread-3 200 http://www.leiphone.com
# Thread-1 200 http://www.17ok.com
# Thread-1 200 http://www.chinaz.com
# Thread-1 200 http://www.youboy.com
# Thread-3 200 http://www.lge.com
# Thread-3 200 http://www.kanxi.cc
# Thread-3 200 http://www.leiphone.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xtx6.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xtx6.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.tutorabc.com
# Thread-5 200 http://www.tutorabc.com
# Thread-5 200 http://www.zhipin.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cgdc.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.zhipin.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cgdc.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 200 http://www.17zwd.com
# Thread-4 200 http://www.17zwd.com
# Thread-5 200 http://www.61learn.com
# Thread-5 200 http://www.61learn.com
# Thread-5 200 http://www.sm.cn
# Thread-5 200 http://www.571xz.com
# Thread-5 200 http://www.sm.cn
# Thread-5 200 http://www.571xz.com
# Thread-5 404 http://www.sobt5.org
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.alibaba.com
# Thread-1 200 http://www.gearbest.com
# Thread-1 200 http://www.51sole.com
# Thread-5 404 http://www.sobt5.org
# Thread-5 200 http://www.starwoodhotels.com
# Thread-5 403 http://www.qqtn.com
# Thread-5 200 http://www.starwoodhotels.com
# Thread-5 403 http://www.qqtn.com
# Thread-1 200 http://www.dbs.com
# Thread-1 200 http://www.suning.com
# Thread-5 200 http://www.sgamer.com
# Thread-5 403 http://www.120ask.com
# Thread-5 200 http://www.sgamer.com
# Thread-5 403 http://www.120ask.com
# Thread-1 403 http://www.oschina.net
# Thread-5 200 http://www.appinn.com
# Thread-1 200 http://www.voc.com.cn
# Thread-1 200 http://www.zol.com.cn
# Thread-5 200 http://www.appinn.com
# Thread-5 200 http://www.qianzhan.com
# Thread-5 200 http://www.qianzhan.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 404 http://www.888pic.com
# Thread-5 404 http://www.888pic.com
# Thread-1 200 http://www.alibaba.com
# Thread-1 200 http://www.gearbest.com
# Thread-1 200 http://www.51sole.com
# Thread-1 200 http://www.dbs.com
# Thread-1 200 http://www.suning.com
# Thread-5 200 http://www.tianyancha.com
# Thread-5 200 http://www.tianyancha.com
# Thread-5 200 http://www.k73.com
# Thread-5 200 http://www.k73.com
# Thread-1 403 http://www.oschina.net
# Thread-1 200 http://www.voc.com.cn
# Thread-5 200 http://www.yiibai.com
# Thread-5 200 http://www.yiibai.com
# Thread-1 200 http://www.zol.com.cn
# Thread-5 200 http://www.downxia.com
# Thread-5 200 http://www.downxia.com
# Thread-5Thread-5 200 http://www.managershare.com
#  200 http://www.managershare.com
# Thread-5 200 http://www.downcc.com
# Thread-5 200 http://www.downcc.com
# Thread-2 200 http://www.hongkongairlines.com
# Thread-2 200 http://www.jxnews.com.cn
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 200 http://www.shfft.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 200 http://www.wanmei.com
# Thread-4 200 http://www.shfft.com
# Thread-4 200 http://www.wanmei.com
# Thread-4 200 http://www.122.gov.cn
# Thread-4 200 http://www.122.gov.cn
# Thread-4 200 http://www.51nb.com
# Thread-4 418 http://www.xici.net
# Thread-4 200 http://www.51nb.com
# Thread-4 418 http://www.xici.net
# Thread-4 200 http://www.cnki.com.cn
# Thread-4 200 http://www.redocn.com
# Thread-4 200 http://www.cnki.com.cn
# Thread-2 200 http://www.hongkongairlines.com
# Thread-4 200 http://www.redocn.com
# Thread-2 200 http://www.jxnews.com.cn
# Thread-2 200 http://www.free.com.tw
# Thread-2 200 http://www.docin.com
# Thread-2 200 http://www.free.com.tw
# Thread-4 200 http://www.qvc.com
# Thread-4 200 http://www.qvc.com
# Thread-2 200 http://www.liepin.com
# Thread-4 200 http://www.aipai.com
# Thread-4 200 http://www.aipai.com
# Thread-2 200 http://www.chinaunix.net
# Thread-4 200 http://www.dapenti.com
# Thread-4 200 http://www.dapenti.com
# Thread-2 200 http://www.docin.com
# Thread-2 200 http://www.weibo.cn
# Thread-2 200 http://www.ifanr.com
# Thread-2 200 http://www.liepin.com
# Thread-2 200 http://www.chinaunix.net
# Thread-4 200 http://www.3lian.com
# Thread-4 200 http://www.3lian.com
# Thread-2 200 http://www.weibo.cn
# Thread-4 200 http://www.guidechem.com
# Thread-4 200 http://www.guidechem.com
# Thread-2 200 http://www.ifanr.com
# Thread-4 200 http://www.jiankang.com
# Thread-4 200 http://www.jiankang.com
# Thread-3Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.51auto.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.tgfcer.com
# Thread-4 200 http://www.tgfcer.com
# Thread-2 200 http://www.ebrun.com
# Thread-4 200 http://www.freebuf.com
# Thread-2 200 http://www.10010.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.51auto.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.hebei.com.cn
# Thread-2 200 http://www.tgbus.com
# Thread-4 200 http://www.freebuf.com
# Thread-2 200 http://www.ebrun.com
# Thread-2 200 http://www.mtime.com
# Thread-2 200 http://www.10010.com
# Thread-2 200 http://www.hebei.com.cn
# Thread-2 200 http://www.vip.com
# Thread-2 200 http://www.tgbus.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.kdslife.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.biquge.tw/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.biquge.tw/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.www.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.mtime.com
# Thread-2 200 http://www.cncn.org.cn
# Thread-2 200 http://www.vip.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 Error:  HTTPSConnectionPool(host='www.kdslife.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.www.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.chinaso.com
# Thread-2 200 http://www.cncn.org.cn
# Thread-4Thread-4 403 http://www.sodao.com
#  403 http://www.sodao.com
# Thread-4Thread-4 200 http://www.zhcw.com
#  200 http://www.zhcw.com
# Thread-1 403 http://www.jianshu.com
# Thread-1 200 http://www.ifeng.com
# Thread-1 200 http://www.stockstar.com
# Thread-1 200 http://www.zhanqi.tv
# Thread-1 200 http://www.52pk.com
# Thread-4 200 Thread-4 200 http://www.sh.com
# http://www.sh.com
# Thread-5 200 http://www.fgowiki.com
# Thread-5 200 http://www.fgowiki.com
# Thread-5 403 http://www.p2peye.com
# Thread-5 403 http://www.p2peye.com
# Thread-4 503 http://www.ablesky.com
# Thread-4 503 http://www.ablesky.com
# Thread-4 200 http://www.microsoftstore.com.cn
# Thread-4 200 http://www.microsoftstore.com.cn
# Thread-4 200 http://www.7k7k.com
# Thread-4 200 http://www.7k7k.com
# Thread-5 200 http://www.haosou.com
# Thread-5 200 http://www.haosou.com
# Thread-4 200 http://www.southmoney.com
# Thread-4 200 http://www.southmoney.com
# Thread-2 200 http://www.techcrunch.com
# Thread-2 200 http://www.techcrunch.com
# Thread-5 200 http://www.yimu100.com
# Thread-5 200 http://www.yimu100.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.chinaso.com
# Thread-2 200 http://www.zbj.com
# Thread-2 200 http://www.zbj.com
# Thread-4 200 http://www.btc123.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://sewer.ip138.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://sewer.ip138.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 403 http://www.jianshu.com
# Thread-2 200 http://www.cyol.com
# Thread-2 200 http://www.cyol.com
# Thread-5 200 http://www.fox.com
# Thread-5 200 http://www.fox.com
# Thread-1 200 http://www.ifeng.com
# Thread-2 200 http://www.pc6.com
# Thread-1 200 http://www.stockstar.com
# Thread-2 200 http://www.pc6.com
# Thread-4 200 http://www.digitaling.com
# Thread-1 200 http://www.zhanqi.tv
# Thread-1 200 http://www.52pk.com
# Thread-4 200 http://www.meitu.com
# Thread-4 200 http://www.chinaaet.com
# Thread-4 200 http://www.kaoyan.com
# Thread-4 200 http://www.aipai.com
# Thread-2 200 http://www.joox.com
# Thread-2 200 http://www.joox.com
# Thread-2 200 http://www.178.com
# Thread-2 200 http://www.178.com
# Thread-4 200 http://www.btc123.com
# Thread-2 200 http://www.lagou.com
# Thread-2 200 http://www.lagou.com
# Thread-4 200 http://www.digitaling.com
# Thread-4 200 http://www.meitu.com
# Thread-4 200 http://www.chinaaet.com
# Thread-2 200 http://www.18183.com
# Thread-2 200 http://www.18183.com
# Thread-4 200 http://www.kaoyan.com
# Thread-4 200 http://www.aipai.com
# Thread-2 200 http://www.365jia.cn
# Thread-2 200 http://www.365jia.cn
# Thread-2 200 http://www.autohome.com.cn
# Thread-2 200 http://www.autohome.com.cn
# Thread-2 200 http://www.battlenet.com.cn
# Thread-2 200 http://www.battlenet.com.cn
# Thread-4 200 http://www.tripadvisor.cn
# Thread-4 200 http://www.colg.cn
# Thread-4 200 http://www.admin5.com
# Thread-2 200 http://www.oracle.com
# Thread-2 405 http://www.miaopai.com
# Thread-2 200 http://www.sina.cn
# Thread-2 200 http://www.oracle.com
# Thread-2 405 http://www.miaopai.com
# Thread-2 200 http://www.ch.com
# Thread-2 200 http://www.sina.cn
# Thread-4 200 http://www.tripadvisor.cn
# Thread-2 200 http://www.ch.com
# Thread-4 200 http://www.colg.cn
# Thread-4 200 http://www.admin5.com
# Thread-2 200 http://www.yxdown.com
# Thread-4 200 http://www.ncar.cc
# Thread-2 200 http://www.yxdown.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.intel.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.wanyx.com
# Thread-1 200 http://www.whatsbuying.com
# Thread-1 200 http://www.cqnews.net
# Thread-2 200 http://www.etao.com
# Thread-1 200 http://www.gongchang.com
# Thread-2 200 http://www.etao.com
# Thread-4 200 http://www.ncar.cc
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.intel.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.wanyx.com
# Thread-1 200 http://www.godaddy.com
# Thread-1 200 http://www.godaddy.com
# Thread-1 200 http://www.whatsbuying.com
# Thread-1 200 http://www.cqnews.net
# Thread-1 200 http://www.wtoip.com
# Thread-1 200 http://www.gongchang.com
# Thread-1 200 http://www.segmentfault.com
# Thread-1 200 http://www.godaddy.com
# Thread-4 200 http://www.chmotor.cn
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.mxhichina.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.jzb.com
# Thread-4 200 http://www.chmotor.cn
# Thread-4 200 http://www.it168.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.mxhichina.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.evernote.com
# Thread-4 200 http://www.jzb.com
# Thread-4 200 http://www.it168.com
# Thread-1 200 http://www.dianping.com
# Thread-1 200 http://www.godaddy.com
# Thread-4 200 http://www.1kkk.com
# Thread-4 200 http://www.1kkk.com
# Thread-1 200 http://www.wtoip.com
# Thread-3Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.segmentfault.com
# Thread-1 200 http://www.qingdaonews.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnodejs.org/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnodejs.org/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 502 http://www.hudong.com
# Thread-4 502 http://www.hudong.com
# Thread-1 200 http://www.guancha.cn
# Thread-3 200 http://www.duomai.com
# Thread-3 200 http://www.duomai.com
# Thread-3 200 http://www.win007.com
# Thread-3 200 http://www.win007.com
# Thread-4 200 http://www.ucweb.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xyw.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.ucweb.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xyw.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.evernote.com
# Thread-3 200 http://www.weidian.com
# Thread-3 200 http://www.weidian.com
# Thread-3 200 http://www.qiku.com
# Thread-3 200 http://www.qiku.com
# Thread-1 200 http://www.dianping.com
# Thread-1 200 http://www.qingdaonews.com
# Thread-1 200 http://www.guancha.cn
# Thread-3 200 http://www.cli.im
# Thread-3 200 http://www.cli.im
# Thread-3 403 http://www.flyertea.com
# Thread-3 403 http://www.flyertea.com
# Thread-3 200 http://www.lenovo.com.cn
# Thread-3 200 http://www.lenovo.com.cn
# Thread-3 200 http://www.aso100.com
# Thread-3 200 http://www.aso100.com
# Thread-1Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.sc.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.sc.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.singaporeair.com
# Thread-1 200 http://www.singaporeair.com
# Thread-3Thread-3 403 http://www.xueqiu.com
#  403 http://www.xueqiu.com
# Thread-1 200 http://www.toutiao.com
# Thread-1 200 http://www.toutiao.com
# Thread-1 200 http://www.jiameng.com
# Thread-3 200 http://www.bp.com
# Thread-3 200 http://www.bp.com
# Thread-1 200 http://www.jiameng.com
# Thread-4 429 http://www.airasiago.com
# Thread-4 429 http://www.airasiago.com
# Thread-1 200 http://www.dm5.com
# Thread-1 200 http://www.dm5.com
# Thread-3Thread-3 200 http://www.dingtalk.com
#  200 http://www.dingtalk.com
# Thread-4 200 http://www.damai.cn
# Thread-4 200 http://www.damai.cn
# Thread-1 200 http://www.w3school.com.cn
# Thread-3 200 http://www.processon.com
# Thread-3 200 http://www.processon.com
# Thread-1 200 http://www.w3school.com.cn
# Thread-3 200 http://www.flyme.cn
# Thread-3 200 http://www.flyme.cn
# Thread-3 200 http://www.a9vg.com
# Thread-3 200 http://www.a9vg.com
# Thread-1 200 http://www.zhaopin.com
# Thread-1 200 http://www.zhaopin.com
# Thread-3 200 http://www.sinaimg.cn
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.saic.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sinaimg.cn
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.saic.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.99.com
# Thread-3 200 http://www.mgtv.com
# Thread-3 200 http://www.mgtv.com
# Thread-1 200 http://www.99.com
# Thread-1 200 http://www.mi.com
# Thread-1 200 http://www.mi.com
# Thread-3 500 http://www.nuomi.com
# Thread-3 500 http://www.nuomi.com
# Thread-1 200 http://www.b2b.cn
# Thread-1 200 http://www.b2b.cn
# Thread-3 200 http://www.tiexue.net
# Thread-3 200 http://www.tiexue.net
# Thread-3 200 http://www.vvvdj.com
# Thread-3 200 http://www.vvvdj.com
# Thread-3 Error:  HTTPSConnectionPool(host='www.tvmao.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 Error:  HTTPSConnectionPool(host='www.tvmao.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.panduoduo.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.panduoduo.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.wechat.com
# Thread-3 200 http://www.wechat.com
# Thread-3 200 http://www.52pojie.cn
# Thread-3 200 http://www.52pojie.cn
# Thread-3 200 http://www.miwifi.com
# Thread-3 200 http://www.miwifi.com
# Thread-3 200 http://www.iteye.com
# Thread-3 200 http://www.iteye.com
# Thread-3 200 http://www.kanzhun.com
# Thread-3 200 http://www.kanzhun.com
# Thread-4 200 http://www.farnell.com
# Thread-4 500 http://www.hi-pda.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.wenku1.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.farnell.com
# Thread-4 500 http://www.hi-pda.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.wenku1.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.haosou.com
# Thread-3 200 http://www.mango.com
# Thread-3 200 http://www.mango.com
# Thread-4 403 http://www.ishuhui.com
# Thread-3 200 http://www.cheaa.com
# Thread-4 200 http://www.paopaoche.net
# Thread-4Thread-3 200 http://www.cheaa.com
#  200 http://www.haosou.com
# Thread-4 403 http://www.ishuhui.com
# Thread-4 200 http://www.csai.cn
# Thread-4 200 http://www.paopaoche.net
# Thread-4 200 http://www.csai.cn
# Thread-5Thread-5 Error:  HTTPSConnectionPool(host='www.mrporter.com', port=443): Read timed out. (read timeout=20)
#  Error:  HTTPSConnectionPool(host='www.mrporter.com', port=443): Read timed out. (read timeout=20)
# Thread-5 530 http://www.genshuixue.com
# Thread-5 530 http://www.genshuixue.com
# Thread-4 200 http://www.zhaoshangbao.com
# Thread-4 200 http://www.zhaoshangbao.com
# Thread-4 200 http://www.eol.cn
# Thread-4 200 http://www.eol.cn
# Thread-4 200 http://www.excelhome.net
# Thread-5 200 http://www.jisutiyu.com
# Thread-5 200 http://www.jisutiyu.com
# Thread-4 200 http://www.excelhome.net
# Thread-4 200 http://www.missevan.com
# Thread-4 200 http://www.missevan.com
# Thread-4 200 http://www.cncv.org.cn
# Thread-4 200 http://www.cncv.org.cn
# Thread-4 200 http://www.365yg.com
# Thread-4 200 http://www.365yg.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.topfo.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.topfo.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.right.com.cn
# ...
# Thread-5 200 http://www.hangame.com
# Thread-5 200 http://www.cngold.org
# Thread-5 200 http://www.hangame.com
# Thread-5 200 http://www.cngold.org
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yindou.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yindou.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error: Thread-2 HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://yao.95095.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sciencenet.cn
# Thread-2 200 http://www.sciencenet.cn
# Thread-5 200 http://www.ishuo.cn
# Thread-3Thread-3 Error:   Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.checheng.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.checheng.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.appgame.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://yao.95095.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.tecenet.com
# Thread-3 200 http://www.appgame.com
# Thread-3 200 http://www.linkhaitao.com
# Thread-3 200 http://www.linkhaitao.com
# Thread-5 200 http://www.ishuo.cn
# Thread-3 200 http://www.meipai.com
# Thread-3 200 http://www.meipai.com
# Thread-3 200 http://www.linuxidc.com
# Thread-3 200 http://www.linuxidc.com
# Thread-5 200 http://www.jinti.com
# Thread-5 200 http://www.tecenet.com
# Thread-5 200 http://www.sobaidupan.com
# Thread-3 200 http://www.fliggy.com
# Thread-5 403 http://www.ichunqiu.com
# Thread-3 200 http://www.fliggy.com
# Thread-5 200 http://www.xilu.com
# Thread-3 200 http://www.amap.com
# Thread-5 200 http://www.jinti.com
# Thread-5 200 http://www.sobaidupan.com
# Thread-3 200 http://www.4px.com
# Thread-3 200 http://www.amap.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.qpic.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 403 http://www.ichunqiu.com
# Thread-3 200 http://www.4px.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.qpic.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.modao.cc
# Thread-2 200 http://www.feiyang.com
# Thread-3 200 http://www.modao.cc
# Thread-2 200 http://www.feiyang.com
# Thread-5 200 http://www.xilu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.3987.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.dianxiaomi.com
# Thread-3 200 http://www.dianxiaomi.com
# Thread-3 200 http://www.56.com
# Exiting Thread-3
# Thread-2 200 http://www.800hr.com
# Thread-4 200 http://www.i1515.com
# Thread-4 200 http://www.i1515.com
# Thread-3 200 http://www.56.com
# Exiting Thread-3
# Thread-4Thread-4 200 http://www.imiker.com
#  200 http://www.imiker.com
# Thread-2 200 http://www.iconfont.cn
# Thread-5 200 http://www.rr-sc.com
# Thread-2 200 http://www.800hr.com
# Thread-4 200 http://www.lvmama.com
# Thread-2 200 http://www.iconfont.cn
# Thread-4 200 http://www.lvmama.com
# Thread-2 200 http://www.youzan.com
# Thread-2 200 http://www.360kan.com
# Thread-2 200 http://www.chinabyte.com
# Thread-2 200 http://www.youzan.com
# Thread-2 200 http://www.samsung.com
# Thread-2 200 http://www.360kan.com
# Thread-2 200 http://www.chinabyte.com
# Thread-2 200 http://www.samsung.com
# Thread-2 200 http://www.zxart.cn
# Thread-2 200 http://www.zxart.cn
# Thread-2 200 http://www.gucheng.com
# Thread-5 200 http://www.99114.com
# Thread-2 200 http://www.bootcss.com
# Thread-2 200 http://www.cankaoxiaoxi.com
# Thread-2 200 http://www.gucheng.com
# Thread-5 200 http://www.haodou.com
# Thread-2 200 http://www.bootcss.com
# Thread-2 200 http://www.cankaoxiaoxi.com
# Thread-2 200 http://www.58pic.com
# Thread-2 200 http://www.81.cn
# Thread-2 200 http://www.58pic.com
# Thread-2 200 http://www.81.cn
# Thread-2 200 http://www.csair.com
# Thread-2 200 http://www.csair.com
# Thread-2 520 http://www.chiphell.com
# Thread-5 200 http://www.wolfram.com
# Thread-2 520 http://www.chiphell.com
# Thread-2Thread-2 403 http://www.antpedia.com
#  403 http://www.antpedia.com
# Thread-2 404 http://www.xiachufang.com
# Thread-2 404 http://www.xiachufang.com
# Thread-2 200 http://www.winshang.com
# Thread-2 200 http://www.winshang.com
# Thread-5 200 http://www.expreview.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.fzg360.com
# Thread-2 200 http://www.fzg360.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 200 http://www.myexception.cn
# Thread-1 200 http://www.qcloud.com
# Thread-5 200 http://www.shixiseng.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bjjs.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.xxbiquge.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.3987.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.rr-sc.com
# Thread-5 200 http://www.99114.com
# Thread-5 200 http://www.haodou.com
# Thread-1 200 http://www.hupu.com
# Thread-5 200 http://www.wolfram.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.lesports.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.hea.cn
# Thread-5 200 http://www.expreview.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.ikanman.com
# Thread-1 200 http://www.3dmgame.com
# Thread-5 200 http://www.myexception.cn
# Thread-1 200 http://www.icolor.com.cn
# Thread-1 200 http://www.360.com
# Thread-1 200 http://www.36kr.com
# Thread-5 200 http://www.shixiseng.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bjjs.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.nowgoal.com
# Thread-4 200 http://www.nowgoal.com
# Thread-1 200 http://www.miui.com
# Thread-1 200 http://www.boc.cn
# Thread-1 200 http://www.gamersky.com
# Thread-5 200 http://www.xxbiquge.com
# Thread-4 200 http://www.makeding.com
# Thread-4 200 http://www.makeding.com
# Thread-1 404 http://www.joyme.com
# Thread-4 200 http://www.xz7.com
# Thread-4 200 http://www.xz7.com
# Thread-1 200 http://www.17173.com
# Thread-4Thread-4 200 http://www.guitarchina.com
#  200 http://www.guitarchina.com
# Thread-4 200 http://www.wto168.net
# Thread-4 200 http://www.wto168.net
# Thread-1 200 http://www.uc.cn
# Thread-4 200 http://www.abchina.com
# Thread-1 200 http://www.alimama.com
# Thread-4 200 http://www.abchina.com
# Thread-4 200 http://www.fzdm.com
# Thread-4 200 http://www.fzdm.com
# Thread-4 200 http://www.ichacha.net
# Thread-4 200 http://www.ichacha.net
# Thread-4 200 http://www.1024sj.com
# Exiting Thread-4
# Thread-4 200 http://www.1024sj.com
# Exiting Thread-4
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.asj.com (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.yeah.net
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.lesports.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.hea.cn
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.qcloud.com
# Thread-1 200 http://www.hupu.com
# Thread-2Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 200 http://www.qcw.com
# Thread-2 200 http://www.12306.cn
# Thread-2 200 http://www.12306.cn
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.morningpost.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.morningpost.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.ikanman.com
# Thread-2 200 http://www.soku.com
# Thread-1 200 http://www.3dmgame.com
# Thread-2 200 http://www.soku.com
# Thread-5 200 http://www.shoes.net.cn
# Thread-1 200 http://www.icolor.com.cn
# Thread-2 200 http://www.sspai.com
# Thread-2 200 http://www.sspai.com
# Thread-5 403 http://www.9c9v.com
# Thread-5 200 http://www.bjhjyd.gov.cn
# Thread-1 200 http://www.360.com
# Thread-5 200 http://www.ecvv.com
# Thread-1 200 http://www.36kr.com
# Thread-1 200 http://www.miui.com
# Thread-1 200 http://www.boc.cn
# Thread-1 200 http://www.gamersky.com
# Thread-1 404 http://www.joyme.com
# Thread-1 200 http://www.17173.com
# Thread-2 200 http://www.yoox.com
# Thread-2 500 http://www.huxiu.com
# Thread-1 200 http://www.uc.cn
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.asj.com (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.alimama.com
# Thread-5 200 http://www.yeah.net
# Thread-2 200 http://www.yoox.com
# Thread-2 500 http://www.huxiu.com
# Thread-2 200 http://www.nyu.edu
# Thread-1 200 http://www.oasgames.com
# Thread-2 403 http://www.jiwu.com
# Thread-5 200 http://www.qcw.com
# Thread-2 200 http://www.u17.com
# Thread-1 200 http://www.focus.cn
# Thread-5 200 http://www.shoes.net.cn
# Thread-1 200 http://www.oasgames.com
# Thread-1 200 http://www.cnr.cn
# Thread-2 200 http://www.jiayuan.com
# Exiting Thread-2
# Thread-2 200 http://www.nyu.edu
# Thread-2 403 http://www.jiwu.com
# Thread-5 403 http://www.9c9v.com
# Thread-5 200 http://www.bjhjyd.gov.cn
# Thread-1 200 http://www.focus.cn
# Thread-1 200 http://www.cnr.cn
# Thread-5 200 http://www.ecvv.com
# Thread-2 200 http://www.u17.com
# Thread-2 200 http://www.jiayuan.com
# Exiting Thread-2
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.fanlibang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.jxmall.com
# Thread-5 403 http://www.xcar.com.cn
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.go108.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.divcss5.com
# Thread-5 200 http://www.sc.com
# Thread-5 200 http://www.watchstore.com.cn
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.fanlibang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.jxmall.com
# Thread-5 403 http://www.xcar.com.cn
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.go108.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.miomio.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.jjwxc.net
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.miomio.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.jjwxc.net
# Thread-5 200 http://www.divcss5.com
# Thread-5 200 http://www.sc.com
# Thread-5 200 http://www.watchstore.com.cn
# Thread-5 200 http://www.mexgroup.com
# Thread-5 200 http://www.mexgroup.com
# Thread-1Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.5dcar.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#  Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.5dcar.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.hjenglish.com
# Thread-1 200 http://www.hjenglish.com
# Thread-1 200 http://www.dangdang.com
# Thread-1 200 http://www.dangdang.com
# Thread-1 200 http://www.springer.com
# Thread-1 503 http://www.to8to.com
# Thread-1 200 http://www.xiaomi.com
# Thread-1 200 http://www.springer.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xunyingwang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 503 http://www.to8to.com
# Thread-5 200 http://www.chinagate.cn
# Thread-5 200 http://www.zdic.net
# Thread-1 200 http://www.xiaomi.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bdimg.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  list index out of range
# Exiting Thread-5
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xunyingwang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.chinagate.cn
# Thread-5 200 http://www.zdic.net
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bdimg.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  list index out of range
# Exiting Thread-5
# Thread-1 200 http://www.ctrip.com
# Thread-1 403 http://www.delta.com
# Thread-1 200 http://www.ctrip.com
# Thread-1 403 http://www.delta.com
# Thread-1 200 http://www.anjuke.com
# Exiting Thread-1
# 简单多线程爬虫的总时间为： 306.7165992259979
# Exiting Main Thread
# Thread-1 200 http://www.anjuke.com
# Exiting Thread-1

# %%
import threading
import requests
import time
import queue as Queue

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)
        
start = time.time()
class myThread (threading.Thread):
    def __init__(self, name, q):
        threading.Thread.__init__(self)
        self.name = name
        self.q = q
    def run(self):
        print ("Starting " + self.name)
        while True:
            try:
                crawler(self.name, self.q)
            except:
                break
        print ("Exiting " + self.name)
        
def crawler(threadName, q):
    url = q.get(timeout=2)
    try:
        r = requests.get(url, timeout=20)
        print (threadName, r.status_code, link_list[i])
    except Exception as e: 
        print(threadName, 'Error: ', e)
        
threadList = ["Thread-1", "Thread-2", "Thread-3","Thread-4", "Thread-5"]
workQueue = Queue.Queue(1000)
threads = []

# 创建新线程
for tName in threadList:
    thread = myThread(tName, workQueue)
    thread.start()
    threads.append(thread)
    
# 填充队列
for url in link_list:
    workQueue.put(url)

# 等待所有线程完成
for t in threads:
    t.join()

end = time.time()
print ('简单多线程爬虫的总时间为：', end-start)
print ("Exiting Main Thread")
# Out:
# Starting Thread-1Starting Thread-2
#
# Starting Thread-3
# Starting Thread-4
# Starting Thread-5
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnzz.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 502 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 503 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 418 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.interpark.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.microsoftonline.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.sc.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.blizzard.com', port=443): Max retries exceeded with url: /?ref=www.battle.net (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(54, 'Connection reset by peer')))
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.alicdn.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.51.la/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.admaimai.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.umeng.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 404 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.miomio.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 503 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.5dcar.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.baiducontent.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-1 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnnic.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 521 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 477 http://www.sohu.com
# Thread-1 Error:  HTTPSConnectionPool(host='www.fobshanghai.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yinyuetai.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPSConnectionPool(host='www.kdslife.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.www.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.51auto.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://sewer.ip138.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 405 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.oracle.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 405 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 404 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 502 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPSConnectionPool(host='chuansongme.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', OSError(0, 'Error')))
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.51job.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 403 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 503 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ccb.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 520 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-5 404 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.morningpost.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 500 http://www.sohu.com
# Thread-4 404 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1Thread-3 200 http://www.sohu.com
#  200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ibuying.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 503 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.tvhome.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 503 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 503 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.dv37.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.114so.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 503 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.saic.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 500 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 Error:  HTTPSConnectionPool(host='www.tvmao.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.panduoduo.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 400 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.lbldy.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.13322.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.f.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yiqifa.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.babyschool.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.020.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.th7.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 502 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.9384.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.9384.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.qpic.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 521 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 521 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.checheng.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.hao6v.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 404 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 503 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPSConnectionPool(host='www.51zxw.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.10086.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.97665.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 418 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 503 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.intel.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.mxhichina.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cnodejs.org/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 502 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xyw.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 500 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 429 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.51yes.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.wenku1.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-2 404 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.chinadmd.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 500 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.btbtdy.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 502 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cicpa.org.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.i2ya.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.jiushang.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://gz.fangdr.com (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.lonshinetech.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.sankuai.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 Error:  HTTPSConnectionPool(host='www.ucas.ac.cn', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)')))
# Thread-5 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.accorhotels.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 400 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.yindou.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.gs307.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ssl-images-amazon.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ecp888.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 405 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.zimuku.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 404 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.dilidili.wang/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.outofmemory.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://ww16.zmz2017.com/?sub1=20201222-1746-4933-8428-9ee6b592c012 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.66ys.tv/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.cgdc.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xp510.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xtx6.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 404 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 403 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 404 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 530 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.topfo.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 502 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 530 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.biquge.tw/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-2 Error:  HTTPSConnectionPool(host='www.mrporter.com', port=443): Read timed out. (read timeout=20)
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.etest.net.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 403 http://www.sohu.com
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-4 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.chinaswitch.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 503 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.ifanjian.net/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.8d.cc/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.sipo.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.a.com.cn/index.html (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Read timed out. (read timeout=20)
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://yao.95095.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.iqing.in/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-5 403 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.3987.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bjjs.gov.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-4 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-1 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 200 http://www.sohu.com
# Thread-3 403 http://www.sohu.com
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.go108.com.cn/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-5 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.lesports.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 200 http://www.sohu.com
# Thread-2 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.bdimg.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-3 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.xunyingwang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Exiting Thread-2
# Exiting Thread-3
# Thread-1 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.fanlibang.com/ (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-4 Error:  HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://www.asj.com (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# Thread-5 200 http://www.sohu.com
# Exiting Thread-1
# Exiting Thread-4
# Exiting Thread-5
# 简单多线程爬虫的总时间为： 339.8914670944214
# Exiting Main Thread

# %% [markdown]
# # 7.3 多进程爬虫

# %%
from multiprocessing import cpu_count
print (cpu_count())
# Out:
# 12

# %% [markdown]
# ## 7.3.1 使用multiprocessing的多进程爬虫

# %%
from multiprocessing import Process, Queue
import time
import requests

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)

start = time.time()
class MyProcess(Process):
    def __init__(self, q):
        Process.__init__(self)
        self.q = q

    def run(self):
        print ("Starting " , self.pid)
        while not self.q.empty():
            crawler(self.q)
        print ("Exiting " , self.pid)

def crawler(q):
    url = q.get(timeout=2)
    try:
        r = requests.get(url, timeout=20)
        print (q.qsize(), r.status_code, url)
    except Exception as e: 
        print (q.qsize(), url, 'Error: ', e)

if __name__ == '__main__':
    ProcessNames = ["Process-1", "Process-2", "Process-3"]
    workQueue = Queue(1000)

    # 填充队列
    for url in link_list:
        workQueue.put(url)

    for i in range(0, 3):
        p = MyProcess(workQueue)
        p.daemon = True
        p.start()
        p.join()

    end = time.time()
    print ('Process + Queue多进程爬虫的总时间为：', end-start)
    print ('Main process Ended!')
# Out:
# Process + Queue多进程爬虫的总时间为： 0.20353984832763672
# Main process Ended!

# %% [markdown]
# ## 7.3.2 使用Pool + Queue的多进程爬虫

# %%
from multiprocessing import Pool, Manager
import time
import requests

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)

start = time.time()
def crawler(q, index):
    Process_id = 'Process-' + str(index)
    while not q.empty():
        url = q.get(timeout=2)
        try:
            r = requests.get(url, timeout=20)
            print (Process_id, q.qsize(), r.status_code, url)
        except Exception as e: 
            print (Process_id, q.qsize(), url, 'Error: ', e)


if __name__ == '__main__':
    manager = Manager()
    workQueue = manager.Queue(1000)

    # 填充队列
    for url in link_list:
        workQueue.put(url)

    pool = Pool(processes=3)
    for i in range(4):
        pool.apply_async(crawler, args=(workQueue, i))

    print ("Started processes")
    pool.close()
    pool.join()

    end = time.time()
    print ('Pool + Queue多进程爬虫的总时间为：', end-start)
    print ('Main process Ended!')

# %% [markdown]
# # 7.4 多协程爬虫

# %%
# !pip install gevent
# Out:
# Requirement already satisfied: gevent in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: greenlet>=0.4.10 in c:\programdata\anaconda3\lib\site-packages (from gevent)

# %%
import gevent
from gevent.queue import Queue, Empty
import time
import requests

from gevent import monkey#把下面有可能有IO操作的单独做上标记
monkey.patch_all() # 将IO转为异步执行的函数

link_list = []
with open('alexa.txt', 'r') as file:
    file_list = file.readlines()
    for eachone in file_list:
        link = eachone.split('\t')[1]
        link = link.replace('\n','')
        link_list.append(link)

start = time.time()
def crawler(index):
    Process_id = 'Process-' + str(index)
    while not workQueue.empty():
        url = workQueue.get(timeout=2)
        try:
            r = requests.get(url, timeout=20)
            print (Process_id, workQueue.qsize(), r.status_code, url)
        except Exception as e: 
            print (Process_id, workQueue.qsize(), url, 'Error: ', e)

def boss():
    for url in link_list:
        workQueue.put_nowait(url)

if __name__ == '__main__':
    workQueue = Queue(1000)

    gevent.spawn(boss).join()
    jobs = []
    for i in range(10):
        jobs.append(gevent.spawn(crawler, i))
    gevent.joinall(jobs)

    end = time.time()
    print ('gevent + Queue多协程爬虫的总时间为：', end-start)
    print ('Main Ended!')

# %% [markdown]
# # 7.5 总结
