# %%
import requests
from bs4 import BeautifulSoup
import datetime

# 获取页面
def get_page(link):
    headers = {'User-Agent' : 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'} 
    r = requests.get(link, headers = headers)
    html = r.content  #使用r.content解封装
    html = html.decode('utf-8')  #由UTF-8解码为unicode
    soup = BeautifulSoup(html, 'lxml')
    return soup

# 解析网页
def get_data(post_list):
    data_list =[]
    for post in post_list:
        title = post.find('div',class_='titlelink box').text.strip()
        post_link = post.find('div',class_='titlelink box').a['href']
        post_link = "https://bbs.hupu.com" + post_link 

        author = post.find('div',class_='author box').a.text.strip()
        author_page = post.find('div',class_='author box').a['href']
        start_date = post.find('div',class_='author box').contents[5].text.strip()

        reply_view = post.find('span',class_='ansour box').text.strip()
        reply = reply_view.split('/')[0].strip()
        view = reply_view.split('/')[1].strip()

        reply_time = post.find('div',class_='endreply box').a.text.strip()
        last_reply = post.find('div',class_='endreply box').span.text.strip()
        if ':' in reply_time: #时间是11:27
            date_time = str(datetime.date.today()) + ' ' + reply_time
            date_time = datetime.datetime.strptime(date_time, '%Y-%m-%d %H:%M')
        elif reply_time.find("-") == 4: #时间是2017-02-27
            date_time = datetime.datetime.strptime(reply_time, '%Y-%m-%d').date()
        else: #时间是11-27
            date_time = datetime.datetime.strptime('2018-' + reply_time, '%Y-%m-%d').date()
        data_list.append([title, post_link, author, author_page, start_date, reply, view, last_reply, date_time])
    return data_list

link = "https://bbs.hupu.com/bxj"
soup = get_page(link)
post_all= soup.find('ul', class_="for-list")
post_list = post_all.find_all('li')
data_list = get_data(post_list)
for each in data_list:
    print (each)
# Out:
# ['[置顶]\n【虎扑✖任天堂】来聊你和NS的故事，赢海量Q币红包雨！\n\n\xa0\n\n[\xa0\n2\n3...20\n\n\xa0]', 'https://bbs.hupu.com/39825238.html', '虎扑的步行街', 'https://my.hupu.com/260395651841167', '2020-12-17', '393', '3341476', '自然醒x', datetime.datetime(2020, 12, 20, 16, 45)]
# ['给需要的jr\n\n\xa0\n\n[\xa0\n2\n3...9\n\n\xa0]', 'https://bbs.hupu.com/39776759.html', '丶不甘', 'https://my.hupu.com/265768964123814', '2020-12-14', '163', '77698', '恩ono呐', datetime.datetime(2020, 12, 20, 18, 48)]
# ['各位大佬救救孩子吧', 'https://bbs.hupu.com/39884111.html', 'KING_ONE', 'https://my.hupu.com/7954895983329', '2020-12-20', '1', '2', 'KING_ONE', datetime.datetime(2020, 12, 20, 18, 48)]
# ['国企研究所单休，领到竟然让我做出这种事!\n\n\xa0\n\n[\xa0\n2\n3...8\n\n\xa0]', 'https://bbs.hupu.com/39881820.html', '质朴星人赖大强', 'https://my.hupu.com/115593883644691', '2020-12-20', '151', '84157', '卡梅罗杜兰特2', datetime.datetime(2020, 12, 20, 18, 48)]
# ['我就觉得自己比丁真帅，咋的？\n\n\xa0\n\n[\xa0\n2\n3...7\n\n\xa0]', 'https://bbs.hupu.com/39883164.html', '科比我爱1', 'https://my.hupu.com/269256260551559', '2020-12-20', '127', '22757', '萌哭大萌神', datetime.datetime(2020, 12, 20, 18, 48)]
# ['一方有难 八方支援 这就是中国力量\n\n\xa0\n\n[\xa0\n2\n3...6\n\n\xa0]', 'https://bbs.hupu.com/39876977.html', '德云基地', 'https://my.hupu.com/53519744250979', '2020-12-20', '100', '108799', '龙l娟', datetime.datetime(2020, 12, 20, 18, 48)]
# ['请问养猫养什么猫脾气性格好一点啊\n\n\xa0\n\n[\xa0\n2\n3\n4\n5\n\n\xa0]', 'https://bbs.hupu.com/39867520.html', '朱鑫鑫同学', 'https://my.hupu.com/160862764358410', '2020-12-19', '99', '43631', '恋爱学教授博导', datetime.datetime(2020, 12, 20, 18, 48)]
# ['老哥们，我现在要怎么办？', 'https://bbs.hupu.com/39883250.html', 'phenom120', 'https://my.hupu.com/85401931406270', '2020-12-20', '5', '732', 'phenom120', datetime.datetime(2020, 12, 20, 18, 48)]
# ['白灼虾  .\n\n\xa0\n\n[\xa0\n2\n3...6\n\n\xa0]', 'https://bbs.hupu.com/39841462.html', '德云基地', 'https://my.hupu.com/53519744250979', '2020-12-18', '106', '90599', 'sc1896', datetime.datetime(2020, 12, 20, 18, 48)]
# ['听说只要打出“只要你不”就好很心酸\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39883141.html', '宜春巴里亚', 'https://my.hupu.com/279958607397455', '2020-12-20', '30', '8357', '西塘人SS', datetime.datetime(2020, 12, 20, 18, 48)]
# ['吴宣仪，小仙女，爱不停', 'https://bbs.hupu.com/39882701.html', '吴宣仪风烧基地', 'https://my.hupu.com/165782803762031', '2020-12-20', '12', '9064', '宝蓝帮你安c4', datetime.datetime(2020, 12, 20, 18, 48)]
# ['从前不信直播带货有多火，现在我信了', 'https://bbs.hupu.com/39882684.html', '九寨沟黄大仙', 'https://my.hupu.com/10361617871016', '2020-12-20', '8', '5238', '赵美延老公', datetime.datetime(2020, 12, 20, 18, 48)]
# ['xdm 虎扑又上微博热搜啦！\n\n\xa0\n\n[\xa0\n2\n3...7\n\n\xa0]', 'https://bbs.hupu.com/39881728.html', '我最帅没人有意见', 'https://my.hupu.com/138690719451600', '2020-12-20', '136', '88791', '方小明12138', datetime.datetime(2020, 12, 20, 18, 48)]
# ['华仔为了拆弹专家找了好多网红呀\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39873129.html', '凯瑞尼古拉斯', 'https://my.hupu.com/271840368810534', '2020-12-19', '53', '41800', '随便逛逛不要管我', datetime.datetime(2020, 12, 20, 18, 48)]
# ['做物流的JR有吗？USPS东西不见了', 'https://bbs.hupu.com/33341457.html', 'ArchiveDreams', 'https://my.hupu.com/221101632646992', '2020-03-30', '3', '915', '虎扑JR0680250000', datetime.datetime(2020, 12, 20, 18, 48)]
# ['第一次网上配镜  感觉还不错', 'https://bbs.hupu.com/39882574.html', '皮志毛', 'https://my.hupu.com/124767454730186', '2020-12-20', '9', '4401', '布川鸿內裤', datetime.datetime(2020, 12, 20, 18, 48)]
# ['有没有一瞬间感觉自己的人生，特别廉价', 'https://bbs.hupu.com/39882928.html', '虎扑JR0032397169', 'https://my.hupu.com/124138830680489', '2020-12-20', '10', '13875', '全州滑扣王', datetime.datetime(2020, 12, 20, 18, 48)]
# ['理性讨论，北方人点菜时说点几个硬菜，到底什么是硬菜，你眼中的硬菜有什么\n\n\xa0\n\n[\xa0\n2\n3...6\n\n\xa0]', 'https://bbs.hupu.com/39882026.html', '凑合过吧还能离是咋滴', 'https://my.hupu.com/172402364319317', '2020-12-20', '110', '25341', '伊犁小冯', datetime.datetime(2020, 12, 20, 18, 48)]
# ['安得烈•塔可夫斯基', 'https://bbs.hupu.com/39877963.html', '披之以诗', 'https://my.hupu.com/157826375209494', '2020-12-20', '1', '3423', '常骚骚', datetime.datetime(2020, 12, 20, 18, 48)]
# ['我真不会喝酒。', 'https://bbs.hupu.com/39865050.html', '电竞鸽神', 'https://my.hupu.com/165257843982691', '2020-12-19', '5', '9836', 'russliu', datetime.datetime(2020, 12, 20, 18, 48)]
# ['最怕的事情发生了\n\n\xa0\n\n[\xa0\n2\n3...28\n\n\xa0]', 'https://bbs.hupu.com/39868806.html', '小毛同学爱小毛', 'https://my.hupu.com/232683878515740', '2020-12-19', '540', '686304', 'Elnino_S', datetime.datetime(2020, 12, 20, 18, 48)]
# ['有谁还记得以前小学课本上的一篇课文——套子里的人', 'https://bbs.hupu.com/39797403.html', '买菜佬', 'https://my.hupu.com/60135106643223', '2020-12-15', '3', '1264', '过后不只是', datetime.datetime(2020, 12, 20, 18, 48)]
# ['萌娃当街撒泼打滚哇哇大哭，90后爸妈站在不远处抱手淡定旁观！\n\n\xa0\n\n[\xa0\n2\n3...7\n\n\xa0]', 'https://bbs.hupu.com/39881083.html', '中国厕所所长', 'https://my.hupu.com/125562057896848', '2020-12-20', '137', '147665', 'Eliaukiu', datetime.datetime(2020, 12, 20, 18, 48)]
# ['我不信这学校还能找到jr\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39865640.html', '啦啦啦wush', 'https://my.hupu.com/87732269270305', '2020-12-19', '68', '53776', '啦啦啦wush', datetime.datetime(2020, 12, 20, 18, 48)]
# ['二十六年前，经典武侠剧《莲花争霸》拍摄花絮', 'https://bbs.hupu.com/39883931.html', '苗可秀', 'https://my.hupu.com/135435097891756', '2020-12-20', '1', '195', '苗可秀', datetime.datetime(2020, 12, 20, 18, 48)]
# ['被学妹当做工具人，现在一下午没理她，接下来怎么办？\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39882806.html', '摇晃的香蕉船', 'https://my.hupu.com/197982773518174', '2020-12-20', '66', '30804', '骚人墨客笔下的烟花', datetime.datetime(2020, 12, 20, 18, 48)]
# ['昨天第一次和女朋友出来玩\n\n\xa0\n\n[\xa0\n2\n3...10\n\n\xa0]', 'https://bbs.hupu.com/39877981.html', '终是李倩化蝶', 'https://my.hupu.com/47766604840605', '2020-12-20', '186', '292078', '把最美好的回忆都锁进了保险柜', datetime.datetime(2020, 12, 20, 18, 48)]
# ['吹爆美的\n\n\xa0\n\n[\xa0\n2\n3...11\n\n\xa0]', 'https://bbs.hupu.com/39862059.html', '我是老JR呀', 'https://my.hupu.com/79030789955796', '2020-12-19', '205', '239390', '阴天求鱼', datetime.datetime(2020, 12, 20, 18, 48)]
# ['哪些事是你们在一起以后你才发现的？\n\n\xa0\n\n[\xa0\n2\n3...8\n\n\xa0]', 'https://bbs.hupu.com/39882348.html', '虎扑JR1559760311', 'https://my.hupu.com/69854030217064', '2020-12-20', '148', '89632', '这里是王solo吖', datetime.datetime(2020, 12, 20, 18, 48)]
# ['为什么练过和没练过的对泰森和普通人之间的认知差距那么大呢？\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39881659.html', '风吹过的雪峰', 'https://my.hupu.com/93048983770189', '2020-12-20', '25', '27341', '梦碎圣城', datetime.datetime(2020, 12, 20, 18, 48)]
# ['一个公务员的相亲之旅\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/
n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39858794.html', '抗忙昂北鼻', 'https://my.hupu.com/58997395755076', '2020-12-19', '42', '30811', 'Xasagi', datetime.datetime(2020, 12, 20, 18, 48)]
# ['是真黑龙江省三亚市啊\n\n\xa0\n\n[\xa0\n2\n3\n4\n5\n\n\xa0]', 'https://bbs.hupu.com/39881214.html', '吊打巴克利', 'https://my.hupu.com/231832595699406', '2020-12-20', '87', '64833', '爬啊', datetime.datetime(2020, 12, 20, 18, 48)]
# ['厦门的jr在不...', 'https://bbs.hupu.com/39876805.html', '安建大', 'https://my.hupu.com/247512401562640', '2020-12-20', '7', '4587', '心中的First', datetime.datetime(2020, 12, 20, 18, 48)]
# ['请各位jr帮忙看看，我这球有没有走步(备福利)', 'https://bbs.hupu.com/39868637.html', '不是不燥i', 'https://my.hupu.com/107570825770658', '2020-12-19', '12', '3782', '努力奋斗别放弃cy', datetime.datetime(2020, 12, 20, 18, 48)]
# ['虎扑再次登上微博热搜……\n\n\xa0\n\n[\xa0\n2\n3...11\n\n\xa0]', 'https://bbs.hupu.com/39881447.html', '毛巾大侠萨叮叮', 'https://my.hupu.com/147954081377267', '2020-12-20', '206', '129345', '马大帅深圳分帅', datetime.datetime(2020, 12, 20, 18, 48)]
# ['卡地亚不配拥有手表\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39881671.html', '云车主', 'https://my.hupu.com/1475035344801', '2020-12-20', '25', '8430', '隐士哲人阿呆', datetime.datetime(2020, 12, 20, 18, 48)]
# ['大学时自以为很潇洒这辈子都不会考公、做老师，毕业后突然感觉我怂了\n\n\xa0\n\n[\xa0\n2\n3\n4\n5\n\n\xa0]', 'https://bbs.hupu.com/39854684.html', '我是变形你是金刚', 'https://my.hupu.com/143801497876658', '2020-12-18', '96', '110848', '火焰神里奥', datetime.datetime(2020, 12, 20, 18, 48)]
# ['战国七雄中为什么秦始皇只灭了六国?\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39883012.html', '布鲁克林篮网队名宿詹姆斯哈登', 'https://my.hupu.com/27303550326595', '2020-12-20', '49', '19345', '步行街舔王之王', datetime.datetime(2020, 12, 20, 18, 48)]
# ['午睡一会，请问午睡几个小时最合适?\n\n\xa0\n\n[\xa0\n2\n3...7\n\n\xa0]', 'https://bbs.hupu.com/39809842.html', '从不黑球员从不被禁言', 'https://my.hupu.com/251263006391796', '2020-12-16', '135', '244118', '鹿之心', datetime.datetime(2020, 12, 20, 18, 48)]
# ['说实话，成都的年轻一代妹子好多肤白貌美大长腿哦', 'https://bbs.hupu.com/39790061.html', 'SABIN1999', 'https://my.hupu.com/229333302688281', '2020-12-15', '8', '2051', 'SABIN1999', datetime.datetime(2020, 12, 20, 18, 48)]
# ['兄弟们，万箭穿心，我该怎么走出去？\n\n\xa0\n\n[\xa0\n2\n3...31\n\n\xa0]', 'https://bbs.hupu.com/39771749.html', '菊花盛开的日子', 'https://my.hupu.com/76101350787969', '2020-12-14', '601', '420124', '俄克拉总冠军', datetime.datetime(2020, 12, 20, 18, 48)]
# ['看起来挺美味\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39877938.html', '熬成球', 'https://my.hupu.com/111754973973089', '2020-12-20', '69', '42643', '寡人有急支糖浆', datetime.datetime(2020, 12, 20, 18, 48)]
# ['是不是我没同情心？感觉看了好爽\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39882254.html', '崛起吧中国男篮', 'https://my.hupu.com/38131780240011', '2020-12-20', '67', '102738', 'BrandonX1ngram', datetime.datetime(2020, 12, 20, 18, 48)]
# ['兄弟们有那张小丑的表情包吗', 'https://bbs.hupu.com/39860467.html', 'LBJ的Abu迷弟', 'https://my.hupu.com/111452336209646', '2020-12-19', '9', '11818', '吴亦凡最skrrr', datetime.datetime(2020, 12, 20, 18, 48)]
# ['浙江省考，综合执法22个人取3个人的岗位\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39881750.html', '58号控球后卫', 'https://my.hupu.com/262746098654594', '2020-12-20', '48', '21215', '正儿八经的大风车', datetime.datetime(2020, 12, 20, 18, 48)]
# ['u1s1 贴牌界的总统山是不是这四个？\n\n\xa0\n\n[\xa0\n2\n3...7\n\n\xa0]', 'https://bbs.hupu.com/39880005.html', 'Akinatatta', 'https://my.hupu.com/190629764996483', '2020-12-20', '120', '155888', '喜欢哈登的大鲸鱼', datetime.datetime(2020, 12, 20, 18, 48)]
# ['江苏省考，裂开，有无锡太湖学院的么\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39878557.html', '昆山小朋友', 'https://my.hupu.com/31281215602303', '2020-12-20', '34', '38182', '小笼包好吃', datetime.datetime(2020, 12, 20, 18, 48)]
# ['2016年里约奥运会，张继科vs丹羽孝希，睡醒之后逆转取胜！', 'https://bbs.hupu.com/39840348.html', '搬运基地', 'https://my.hupu.com/221311000669643', '2020-12-18', '20', '13464', '绝境看梅罗', datetime.datetime(2020, 12, 20, 18, 48)]
# ['为什么重庆阴雨天这么多？', 'https://bbs.hupu.com/39882752.html', '彳亍哥欠', 'https://my.hupu.com/116447758641170', '2020-12-20', '6', '1894', 'AIwithLBJ', datetime.datetime(2020, 12, 20, 18, 48)]
# ['急需众筹H币\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39880166.html', '硬綁綁', 'https://my.hupu.com/252380728038279', '2020-12-20', '29', '10721', '可莉与七七', datetime.datetime(2020, 12, 20, 18, 47)]
# ['这滞空太强了\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39878232.html', '陈冠希CI', 'https://my.hupu.com/2742604760049', '2020-12-20', '21', '22860', '李敖大师', datetime.datetime(2020, 12, 20, 18, 47)]
# ['北方人买肉都这么猛吗？不服不行啊，这这买一次够吃一个月了，但这些太爽了！\n\n\xa0\n\n[\xa0\n2\n3...6\n\n\xa0]', 'https://bbs.hupu.com/39881193.html', '中国厕所所长', 'https://my.hupu.com/125562057896848', '2020-12-20', '119', '73512', '兴华集团发来贺电', datetime.datetime(2020, 12, 20, 18, 47)]
# ['公安局长怒了，军统鬼子六竟敢说自己是共产党\n\n\xa0\n\n[\xa0\n2\n3...6\n\n\xa0]', 'https://bbs.hupu.com/39880900.html', '苗可秀', 'https://my.hupu.com/135435097891756', '2020-12-20', '101', '122130', '皮尔斯pp', datetime.datetime(2020, 12, 20, 18, 47)]
# ['第一次网恋被骗钱了。\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39882482.html', '梦想就是去拼', 'https://my.hupu.com/234521866338097', '2020-12-20', '23', '5988', '本命英雄杰斯', datetime.datetime(2020, 12, 20, 18, 47)]
# ['饥荒大佬进来看啊！', 'https://bbs.hupu.com/39877521.html', '记得傻笑', 'https://my.hupu.com/242434155159950', '2020-12-20', '2', '6106', 'Holmesyyl', datetime.datetime(2020, 12, 20, 18, 47)]
# ['求问jrs，男朋友死活不让我看他打篮球赛正常吗？\n\n\xa0\n\n[\xa0\n2\n3...8\n\n\xa0]', 'https://bbs.hupu.com/39869152.html', '星子放入眸', 'https://my.hupu.com/188036569526325', '2020-12-19', '145', '51916', 'kkuui', datetime.datetime(2020, 12, 20, 18, 47)]
# ['同位宿迁人，刘强东和项羽谁的历史地位更高？\n\n\xa0\n\n[\xa0\n2\n3\n4\n5\n\n\xa0]', 'https://bbs.hupu.com/39881914.html', '擦你的嘴啊', 'https://my.hupu.com/84181045143814', '2020-12-20', '87', '30298', '维京金属狂潮', datetime.datetime(2020, 12, 20, 18, 47)]
# ['微博请求跟咱们中门对狙，这波怎么看\n\n\xa0\n\n[\xa0\n2\n3...9\n\n\xa0]', 'https://bbs.hupu.com/39881652.html', 'MoreXD', 'https://my.hupu.com/51041881526479', '2020-12-20', '163', '86407', 'A.Shevchenko-7', datetime.datetime(2020, 12, 20, 18, 47)]
# ['珠三角城市群和长三角城市群，哪个经济更强？\n\n\xa0\n\n[\xa0\n2\n3...16\n\n\xa0]', 'https://bbs.hupu.com/39880218.html', '场均48分钟', 'https://my.hupu.com/179630028493817', '2020-12-20', '309', '140720', '拉风的昵称啊chao', datetime.datetime(2020, 12, 20, 18, 47)]
# ['北京生活不容易。\n\n\xa0\n\n[\xa0\n2\n3...10\n\n\xa0]', 'https://bbs.hupu.com/39879566.html', '令狐冲Duang', 'https://my.hupu.com/129381414194967', '2020-12-20', '199', '85547', '奶牛Federer', datetime.datetime(2020, 12, 20, 18, 47)]
# ['我说的与我妈听到的', 'https://bbs.hupu.com/39882696.html', '贾君鹏的妈妈', 'https://my.hupu.com/234342780624741', '2020-12-20', '8', '3358', '零四年第一顺位', datetime.datetime(2020, 12, 20, 18, 47)]
# ['李林四套卷第四张线代最后一问', 'https://bbs.hupu.com/39881224.html', '我罗依旧绽放', 'https://my.hupu.com/221644994462002', '2020-12-20', '17', '6215', '再见一九九五', datetime.datetime(2020, 12, 20, 18, 47)]
# ['二选一，林志颖的相貌和王思聪的财富，选哪个？', 'https://bbs.hupu.com/39880483.html', 'YOYO夏天', 'https://my.hupu.com/29827116827983', '2020-12-20', '15', '5774', '野区吸血鬼', datetime.datetime(2020, 12, 20, 18, 47)]
# ['清理手机内存翻到一年前刚上大学没几天和喜欢的学姐的聊天记录，心里挺难受的\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39812204.html', '随便逛逛i', 'https://my.hupu.com/251277482533614', '2020-12-16', '59', '84839', '陈小软', datetime.datetime(2020, 12, 20, 18, 47)]
# ['考虑房价和工资水平，武汉和青岛哪个更宜居？\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39881049.html', 'Jrnvxxh5bhgf', 'https://my.hupu.com/67871141023943', '2020-12-20', '26', '13694', 'LBDW_YPS', datetime.datetime(2020, 12, 20, 18, 47)]
# ['奥特曼中的武器大师——杰克奥特曼\n\n\xa0\n\n[\xa0\n2\n3...8\n\n\xa0]', 'https://bbs.hupu.com/39877884.html', '搬运基地', 'https://my.hupu.com/221311000669643', '2020-12-20', '154', '310465', '你撒开我', datetime.datetime(2020, 12, 20, 18, 47)]
# ['在探探上被女同学发现什么水平？', 'https://bbs.hupu.com/39884105.html', '世间有我真幸运', 'https://my.hupu.com/221179013951525', '2020-12-20', '0', '3', '世间有我真幸运', datetime.datetime(2020, 12, 20, 18, 47)]
# ['如何评价周杰伦2005年的专辑《十一月的肖邦》？你喜欢里面哪些歌？\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39879038.html', '我愿潇洒如鹰逆风等待黎明', 'https://my.hupu.com/177176889117846', '2020-12-20', '69', '47641', 'Tim咖喱', datetime.datetime(2020, 12, 20, 18, 47)]
# ['今年考研希望不大，有必要二战吗\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39882549.html', '尽头人', 'https://my.hupu.com/250510087017450', '2020-12-20', '25', '4658', '联盟第一中锋怀斯曼', datetime.datetime(2020, 12, 20, 18, 47)]
# ['应届生的迷茫', 'https://bbs.hupu.com/39883554.html', '我是保罗仔', 'https://my.hupu.com/187675013600457', '2020-12-20', '1', '531', '是Season啊', datetime.datetime(2020, 12, 20, 18, 47)]
# ['江苏省考 裂开\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39878077.html', 'LinsanityˋY', 'https://my.hupu.com/108443800601479', '2020-12-20', '53', '66879', '灰色天', datetime.datetime(2020, 12, 20, 18, 47)]
# ['有了解医院运作的同胞来解释下为何能动员如此多的医务工作者？', 'https://bbs.hupu.com/39882474.html', '三七二十几', 'https://my.hupu.com/169768353489395', '2020-12-20', '11', '3516', '格林除了会踢蛋还会干嘛', datetime.datetime(2020, 12, 20, 18, 47)]
# ['快27了，没谈过恋爱，要不要告诉马上要交往的对象?\n\n\xa0\n\n[\xa0\n2\n3...15\n\n\xa0]', 'https://bbs.hupu.com/39877109.html', '不想长rou了', 'https://my.hupu.com/153530741642138', '2020-12-20', '289', '397075', '用户1452309844', datetime.datetime(2020, 12, 20, 18, 47)]
# ['数学家利用漏洞狂买彩票中1.7亿，官方：合法，不会追回！\n\n\xa0\n\n[\xa0\n2\n3...11\n\n\xa0]', 'https://bbs.hupu.com/39881620.html', 'y十九遇她x', 'https://my.hupu.com/245680512596600', '2020-12-20', '207', '321488', '粘糕一只', datetime.datetime(2020, 12, 20, 18, 47)]
# ['急,老婆要我房产证加她名字，我该怎么办\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39878579.html', 'Siweiway', 'https://my.hupu.com/15417772303368', '2020-12-20', '77', '120964', '321mnbvcxz', datetime.datetime(2020, 12, 20, 18, 47)]
# ['刚吃了碗牛杂汤，看到这块肉感觉不对劲，是不是淋巴肉？\n\n\xa0\n\n[\xa0\n2\n3\n4\n5\n\n\xa0]', 'https://bbs.hupu.com/39778293.html', '诺基亚N70', 'https://my.hupu.com/69729732309192', '2020-12-14', '84', '179318', '屋檐下的蓝皮鼠', datetime.datetime(2020, 12, 20, 18, 47)]
# ['美国usps快递3个月没到中国不知道怎么办求帮助大哥大姐们！', 'https://bbs.hupu.com/31692998.html', '詹姆斯拥抱韦德', 'https://my.hupu.com/108750983191999', '2020-01-08', '1', '694', '虎扑JR0680250000', datetime.datetime(2020, 12, 20, 18, 47)]
# ['有没有在上海浦东丽思卡尔顿工作的jr！\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39871777.html', '笛短萧长', 'https://my.hupu.com/253245459037490', '2020-12-19', '30', '45344', '我至今犹在等候', datetime.datetime(2020, 12, 20, 18, 47)]
# ['这是啥子意思?', 'https://bbs.hupu.com/39832474.html', '用户1965284239', 'https://my.hupu.com/98158670078089', '2020-12-17', '5', '10976', '当科比遇到布莱恩特', datetime.datetime(2020, 12, 20, 18, 47)]
# ['京东有货不发，逼客户退款', 'https://bbs.hupu.com/39883184.html', '独上高楼I望尽天涯路', 'https://my.hupu.com/89907513832458', '2020-12-20', '8', '2054', '虎扑JR1437804231', datetime.datetime(2020, 12, 20, 18, 47)]
# ['下班了来一个烤冷面，真香！\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/
# ['这个活检报告描述是什么意思\n\n\xa0\n\n[\xa0\n2\n\n\xa0]', 'https://bbs.hupu.com/39881898.html', '在多瑙河买河粉的猫', 'https://my.hupu.com/47059526756961', '2020-12-20', '27', '11569', 'HL198', datetime.datetime(2020, 12, 20, 18, 47)]
# ['再来一年还有必要吗？\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39880169.html', '仔笨主义', 'https://my.hupu.com/162767104995251', '2020-12-20', '58', '18452', '三重刘德华11', datetime.datetime(2020, 12, 20, 18, 47)]
# ['各位博导，民办本科专任教师怎么样？\n\n\xa0\n\n[\xa0\n2\n3\n\n\xa0]', 'https://bbs.hupu.com/39877820.html', '艺术是世界与大地的冲突丢傻嗨', 'https://my.hupu.com/84137185891611', '2020-12-20', '49', '45804', '21年我要上岸', datetime.datetime(2020, 12, 20, 18, 47)]
# ['还有几天就考研了 我确放弃了\n\n\xa0\n\n[\xa0\n2\n3\n4\n\n\xa0]', 'https://bbs.hupu.com/39865494.html', '骑马怼飞机', 'https://my.hupu.com/71333602578621', '2020-12-19', '64', '94805', '美丽的勒布朗詹姆斯', datetime.datetime(2020, 12, 20, 18, 47)]

# %%
from pymongo import MongoClient
class MongoAPI(object):
    def __init__(self, db_ip, db_port, db_name, table_name):
        self.db_ip = db_ip
        self.db_port = db_port
        self.db_name = db_name
        self.table_name = table_name
        self.conn = MongoClient(host=self.db_ip, port=self.db_port)
        self.db = self.conn[self.db_name]
        self.table = self.db[self.table_name]
    def get_one(self, query):
        return self.table.find_one(query, projection={"_id": False})
    def get_all(self, query):
        return self.table.find(query)
    def add(self, kv_dict):
        return self.table.insert(kv_dict)
    def delete(self, query):
        return self.table.delete_many(query)
    def check_exist(self, query):
        ret = self.table.find_one(query)
        return ret != None
    # 如果没有会新建
    def update(self, query, kv_dict):
            self.table.update_one(query,{
              '$set': kv_dict
            }, upsert=True)

# %%
hupu_post = MongoAPI("localhost",  27017,  "hupu", "post")
for each in data_list:
    hupu_post.add({"title": each[0], 
                "post_link": each[1],
               "author": each[2],
               "author_page": each[3],
               "start_date": str(each[4]),
               "reply": each[5],
               "view": each[6],
               "last_reply": each[7],
               "last_reply_time": str(each[8])})
# Out:
# <ipython-input-2-16a298c5d647>:16: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   return self.table.insert(kv_dict)

# %%
import requests
from bs4 import BeautifulSoup
import datetime
from pymongo import MongoClient
import time

hupu_post = MongoAPI("localhost",  27017,  "hupu", "post")
for i in range(1,100):
    link = "https://bbs.hupu.com/bxj-" + str(i)
    soup = get_page(link)
    
    post_all= soup.find('ul', class_="for-list")
    post_list = post_all.find_all('li')
    data_list = get_data(post_list)
    for each in data_list:
        hupu_post.update({"post_link": each[1]},{"title": each[0], 
                    "post_link": each[1],
                   "author": each[2],
                   "author_page": each[3],
                   "start_date": str(each[4]),
                   "reply": each[5],
                   "view": each[6],
                   "last_reply": each[7],
                   "last_reply_time": str(each[8])})
    time.sleep(3)
    print ('第', i ,'页获取完成，休息3秒')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9cfe519c318c> in <module>
#      11
#      12     post_all= soup.find('ul', class_="for-list")
# ---> 13     post_list = post_all.find_all('li')
#      14     data_list = get_data(post_list)
#      15     for each in data_list:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
